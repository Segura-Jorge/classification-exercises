# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

import scipy as sp
from pydataset import data
from env import get_db_url, user, password, host
from scipy import stats
import warnings
warnings.filterwarnings("ignore")

import acquire as acq
#import prepare as pre
import os
directory = os.getcwd()

# %% [markdown]
# ## Using the Titanic dataset
#
# #### 1. Use the function defined in `acquire.py` to load the Titanic data.

# %% [markdown]
# #### 2. Use the function defined in `prepare.py` to prepare the titanic data.

# %%
titanic = acq.get_titanic_data()
titanic.head()
# Out:
#    Unnamed: 0  passenger_id  survived  pclass     sex   age  sibsp  parch  \
# 0           0             0         0       3    male  22.0      1      0
# 1           1             1         1       1  female  38.0      1      0
# 2           2             2         1       3  female  26.0      0      0
# 3           3             3         1       1  female  35.0      1      0
# 4           4             4         0       3    male  35.0      0      0
#
#       fare embarked  class deck  embark_town  alone
# 0   7.2500        S  Third  NaN  Southampton      0
# 1  71.2833        C  First    C    Cherbourg      0
# 2   7.9250        S  Third  NaN  Southampton      1
# 3  53.1000        S  First    C  Southampton      0
# 4   8.0500        S  Third  NaN  Southampton      1

# %%
titanic = acq.prep_titanic(acq.get_titanic_data())
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  embark_town  alone
# 0         0       3    male  22.0      1      0   7.2500  Southampton      0
# 1         1       1  female  38.0      1      0  71.2833    Cherbourg      0
# 2         1       3  female  26.0      0      0   7.9250  Southampton      1
# 3         1       1  female  35.0      1      0  53.1000  Southampton      0
# 4         0       3    male  35.0      0      0   8.0500  Southampton      1

# %%
train, val, test = acq.split_data(titanic,'titanic')
train.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare  embark_town  alone
# 829         1       1  female  62.0      0      0  80.000  Southampton      1
# 463         0       2    male  48.0      0      0  13.000  Southampton      1
# 228         0       2    male  18.0      0      0  13.000  Southampton      1
# 374         0       3  female   3.0      3      1  21.075  Southampton      0
# 494         0       3    male  21.0      0      0   8.050  Southampton      1

# %% [markdown]
# #### 3. Encode the categorical columns on train dataset. Create dummy variables of the categorical columns and concatenate them onto the dataframe. Remove the columns they are replacing. Repeat on validate and test.

# %%
train.loc[:, 'is_female'] = (train.sex == 'female').astype(int)

# %%
train.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare  embark_town  alone  \
# 829         1       1  female  62.0      0      0  80.000  Southampton      1
# 463         0       2    male  48.0      0      0  13.000  Southampton      1
# 228         0       2    male  18.0      0      0  13.000  Southampton      1
# 374         0       3  female   3.0      3      1  21.075  Southampton      0
# 494         0       3    male  21.0      0      0   8.050  Southampton      1
#
#      is_female
# 829          1
# 463          0
# 228          0
# 374          1
# 494          0

# %%
train[['is_queenstown', 'is_southampton']] = pd.get_dummies(train.embark_town,
               drop_first=True).astype(int).values
train.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare  embark_town  alone  \
# 829         1       1  female  62.0      0      0  80.000  Southampton      1
# 463         0       2    male  48.0      0      0  13.000  Southampton      1
# 228         0       2    male  18.0      0      0  13.000  Southampton      1
# 374         0       3  female   3.0      3      1  21.075  Southampton      0
# 494         0       3    male  21.0      0      0   8.050  Southampton      1
#
#      is_female  is_queenstown  is_southampton
# 829          1              0               1
# 463          0              0               1
# 228          0              0               1
# 374          1              0               1
# 494          0              0               1

# %%
train = train.drop(columns = 'embark_town')

# %%
train.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare  alone  is_female  \
# 829         1       1  female  62.0      0      0  80.000      1          1
# 463         0       2    male  48.0      0      0  13.000      1          0
# 228         0       2    male  18.0      0      0  13.000      1          0
# 374         0       3  female   3.0      3      1  21.075      0          1
# 494         0       3    male  21.0      0      0   8.050      1          0
#
#      is_queenstown  is_southampton
# 829              0               1
# 463              0               1
# 228              0               1
# 374              0               1
# 494              0               1

# %%
continuous_features = ['age', 'fare_x_pass']
scaler = MinMaxScaler()

# %% [markdown]
# #### 4. Create a function named `preprocess_titanic` that accepts the train, validate, and test titanic data, and returns the dataframes ready for modeling.

# %%
train, val, test = acq.split_data(titanic, 'titanic')
train.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare  embark_town  alone
# 829         1       1  female  62.0      0      0  80.000  Southampton      1
# 463         0       2    male  48.0      0      0  13.000  Southampton      1
# 228         0       2    male  18.0      0      0  13.000  Southampton      1
# 374         0       3  female   3.0      3      1  21.075  Southampton      0
# 494         0       3    male  21.0      0      0   8.050  Southampton      1

# %%
def preprocess_titanic(train, val, test, continuous_features=['age', 'fare']):
    '''
    preprocess titanic will encode any categorical features
    and proceed forward with using a minmax scaler to transform 
    continuous variables.
    
    return: three dataframes, train, validate, and test, preprocessed for modeling
    '''
    # iterate through our three dataframes
    for df in [train, val, test]:
        # assign out the encoded categoricals for embark_town
        # in the same way on all three datasets
        df[['is_queenstown', 'is_southampton']] = pd.get_dummies(df.embark_town,
               drop_first=True).astype(int).values
        # added a column that divides fare to the total in tickets bough in that transaction
        df['fare_x_pass'] = df['fare'] / (df['sibsp'] + df['parch'] + df['alone']).astype(float)
    # create a single scaler object
    scaler = MinMaxScaler()
    # fit the single scaler just once to train
    scaler.fit(train[continuous_features])
    # apply that transformation to all three data sets
    # using the same syntax, which conconates
    # '_scaled' to each feature name that was fed in
    for df in [train, val, test]:
        df[[continuous_features[0]+'_scaled', continuous_features[1]+'_scaled']] = \
        scaler.transform(df[continuous_features])
    for df in [train, val, test]:
        df['is_female'] = np.where(df['sex'] == 'female', 1, 0)
    preprocessed_dfs = []
    for df in [train, val, test]:
        preprocessed_dfs.append(df.drop(columns=['sex', 'age', 'fare', 'embark_town']))
    return preprocessed_dfs

# %%
train_processed, val_processed, test_processed = preprocess_titanic(train, val, test)

# %%
train_processed.head()
# Out:
#      survived  pclass  sibsp  parch  alone  is_queenstown  is_southampton  \
# 829         1       1      0      0      1              0               1
# 463         0       2      0      0      1              0               1
# 228         0       2      0      0      1              0               1
# 374         0       3      3      1      0              0               1
# 494         0       3      0      0      1              0               1
#
#      age_scaled  fare_scaled  is_female  fare_x_pass
# 829    0.773813     0.156150          1     80.00000
# 463    0.597889     0.025374          0     13.00000
# 228    0.220910     0.025374          0     13.00000
# 374    0.032420     0.041136          1      5.26875
# 494    0.258608     0.015713          0      8.05000

# %% [markdown]
# ## Using the Telco dataset
#
# #### 1. Use the function defined in `acquire.py` to load the Telco data.

# %%
telco = acq.get_telco_data()
telco.head()
# Out:
#    Unnamed: 0  payment_type_id  internet_service_type_id  contract_type_id  \
# 0           0                2                         1                 2
# 1           1                2                         1                 1
# 2           2                1                         2                 1
# 3           3                1                         2                 1
# 4           4                2                         2                 1
#
#   customer_id  gender  senior_citizen partner dependents  tenure  ...  \
# 0  0002-ORFBO  Female               0     Yes        Yes       9  ...
# 1  0003-MKNFE    Male               0      No         No       9  ...
# 2  0004-TLHLJ    Male               0      No         No       4  ...
# 3  0011-IGKFF    Male               1     Yes         No      13  ...
# 4  0013-EXCHZ  Female               1     Yes         No       3  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# 0          Yes          Yes               No               Yes
# 1           No           No              Yes                No
# 2           No           No               No               Yes
# 3           No          Yes              Yes               Yes
# 4          Yes          Yes               No               Yes
#
#   monthly_charges total_charges churn   contract_type internet_service_type  \
# 0            65.6         593.3    No        One year                   DSL
# 1            59.9         542.4    No  Month-to-month                   DSL
# 2            73.9        280.85   Yes  Month-to-month           Fiber optic
# 3            98.0       1237.85   Yes  Month-to-month           Fiber optic
# 4            83.9         267.4   Yes  Month-to-month           Fiber optic
#
#        payment_type
# 0      Mailed check
# 1      Mailed check
# 2  Electronic check
# 3  Electronic check
# 4      Mailed check
#
# [5 rows x 25 columns]

# %% [markdown]
# #### 2. Use the function defined in `prepare.py` to prepare the Telco data.

# %%
telco = acq.prep_telco(telco)
telco.head()
# Out:
#              gender  senior_citizen partner dependents  tenure phone_service  \
# customer_id
# 0002-ORFBO   Female               0     Yes        Yes       9           Yes
# 0003-MKNFE     Male               0      No         No       9           Yes
# 0004-TLHLJ     Male               0      No         No       4           Yes
# 0011-IGKFF     Male               1     Yes         No      13           Yes
# 0013-EXCHZ   Female               1     Yes         No       3           Yes
#
#             multiple_lines online_security online_backup device_protection  \
# customer_id
# 0002-ORFBO              No              No           Yes                No
# 0003-MKNFE             Yes              No            No                No
# 0004-TLHLJ              No              No            No               Yes
# 0011-IGKFF              No              No           Yes               Yes
# 0013-EXCHZ              No              No            No                No
#
#             tech_support streaming_tv streaming_movies paperless_billing  \
# customer_id
# 0002-ORFBO           Yes          Yes               No               Yes
# 0003-MKNFE            No           No              Yes                No
# 0004-TLHLJ            No           No               No               Yes
# 0011-IGKFF            No          Yes              Yes               Yes
# 0013-EXCHZ           Yes          Yes               No               Yes
#
#              monthly_charges  total_charges churn   contract_type  \
# customer_id
# 0002-ORFBO              65.6         593.30    No        One year
# 0003-MKNFE              59.9         542.40    No  Month-to-month
# 0004-TLHLJ              73.9         280.85   Yes  Month-to-month
# 0011-IGKFF              98.0        1237.85   Yes  Month-to-month
# 0013-EXCHZ              83.9         267.40   Yes  Month-to-month
#
#             internet_service_type      payment_type
# customer_id
# 0002-ORFBO                    DSL      Mailed check
# 0003-MKNFE                    DSL      Mailed check
# 0004-TLHLJ            Fiber optic  Electronic check
# 0011-IGKFF            Fiber optic  Electronic check
# 0013-EXCHZ            Fiber optic      Mailed check

# %%
train, val, test = acq.split_data(telco, 'telco')
train.head()
# Out:
#              gender  senior_citizen partner dependents  tenure phone_service  \
# customer_id
# 7439-DKZTW     Male               0      No         No       1           Yes
# 0557-ASKVU   Female               0     Yes        Yes      18           Yes
# 7255-SSFBC     Male               0     Yes        Yes      72           Yes
# 0311-QYWSS   Female               0      No         No       6           Yes
# 1926-QUZNN   Female               0     Yes         No      72           Yes
#
#             multiple_lines      online_security        online_backup  \
# customer_id
# 7439-DKZTW              No                   No                   No
# 0557-ASKVU              No                   No                   No
# 7255-SSFBC             Yes                   No                  Yes
# 0311-QYWSS              No                  Yes                   No
# 1926-QUZNN             Yes  No internet service  No internet service
#
#                device_protection         tech_support         streaming_tv  \
# customer_id
# 7439-DKZTW                    No                   No                  Yes
# 0557-ASKVU                   Yes                  Yes                   No
# 7255-SSFBC                   Yes                  Yes                  Yes
# 0311-QYWSS                    No                   No                   No
# 1926-QUZNN   No internet service  No internet service  No internet service
#
#                 streaming_movies paperless_billing  monthly_charges  \
# customer_id
# 7439-DKZTW                    No               Yes            80.55
# 0557-ASKVU                    No               Yes            54.40
# 7255-SSFBC                   Yes               Yes           112.25
# 0311-QYWSS                    No               Yes            49.45
# 1926-QUZNN   No internet service               Yes            25.25
#
#              total_charges churn   contract_type internet_service_type  \
# customer_id
# 7439-DKZTW           80.55    No  Month-to-month           Fiber optic
# 0557-ASKVU          957.10    No        One year                   DSL
# 7255-SSFBC         8041.65    No        Two year           Fiber optic
# 0311-QYWSS          314.60    No  Month-to-month                   DSL
# 1926-QUZNN         1841.20    No        Two year                  None
#
#                           payment_type
# customer_id
# 7439-DKZTW            Electronic check
# 0557-ASKVU     Credit card (automatic)
# 7255-SSFBC   Bank transfer (automatic)
# 0311-QYWSS            Electronic check
# 1926-QUZNN   Bank transfer (automatic)

# %%
#train.loc[:, 'Month-to-month'] = (train.contract_type == 'Month-to-month').astype(int)
#train.head()

# %%
train[['One_year_con', 'Two_year_con']] = pd.get_dummies(train.contract_type,
               drop_first=True).astype(int).values
train.head()
# Out:
#              gender  senior_citizen partner dependents  tenure phone_service  \
# customer_id
# 7439-DKZTW     Male               0      No         No       1           Yes
# 0557-ASKVU   Female               0     Yes        Yes      18           Yes
# 7255-SSFBC     Male               0     Yes        Yes      72           Yes
# 0311-QYWSS   Female               0      No         No       6           Yes
# 1926-QUZNN   Female               0     Yes         No      72           Yes
#
#             multiple_lines      online_security        online_backup  \
# customer_id
# 7439-DKZTW              No                   No                   No
# 0557-ASKVU              No                   No                   No
# 7255-SSFBC             Yes                   No                  Yes
# 0311-QYWSS              No                  Yes                   No
# 1926-QUZNN             Yes  No internet service  No internet service
#
#                device_protection  ...     streaming_movies paperless_billing  \
# customer_id                       ...
# 7439-DKZTW                    No  ...                   No               Yes
# 0557-ASKVU                   Yes  ...                   No               Yes
# 7255-SSFBC                   Yes  ...                  Yes               Yes
# 0311-QYWSS                    No  ...                   No               Yes
# 1926-QUZNN   No internet service  ...  No internet service               Yes
#
#             monthly_charges total_charges  churn   contract_type  \
# customer_id
# 7439-DKZTW            80.55         80.55     No  Month-to-month
# 0557-ASKVU            54.40        957.10     No        One year
# 7255-SSFBC           112.25       8041.65     No        Two year
# 0311-QYWSS            49.45        314.60     No  Month-to-month
# 1926-QUZNN            25.25       1841.20     No        Two year
#
#             internet_service_type               payment_type One_year_con  \
# customer_id
# 7439-DKZTW            Fiber optic           Electronic check            0
# 0557-ASKVU                    DSL    Credit card (automatic)            1
# 7255-SSFBC            Fiber optic  Bank transfer (automatic)            0
# 0311-QYWSS                    DSL           Electronic check            0
# 1926-QUZNN                   None  Bank transfer (automatic)            0
#
#             Two_year_con
# customer_id
# 7439-DKZTW             0
# 0557-ASKVU             0
# 7255-SSFBC             1
# 0311-QYWSS             0
# 1926-QUZNN             1
#
# [5 rows x 22 columns]

# %%
train.payment_type.value_counts()
# Out:
# Electronic check             1407
# Mailed check                  946
# Credit card (automatic)       937
# Bank transfer (automatic)     935
# Name: payment_type, dtype: int64

# %%
train.loc[:, 'has_phone_service'] = (train.phone_service == 'Yes').astype(int)
train.head()
# Out:
#              gender  senior_citizen partner dependents  tenure phone_service  \
# customer_id
# 7439-DKZTW     Male               0      No         No       1           Yes
# 0557-ASKVU   Female               0     Yes        Yes      18           Yes
# 7255-SSFBC     Male               0     Yes        Yes      72           Yes
# 0311-QYWSS   Female               0      No         No       6           Yes
# 1926-QUZNN   Female               0     Yes         No      72           Yes
#
#             multiple_lines      online_security        online_backup  \
# customer_id
# 7439-DKZTW              No                   No                   No
# 0557-ASKVU              No                   No                   No
# 7255-SSFBC             Yes                   No                  Yes
# 0311-QYWSS              No                  Yes                   No
# 1926-QUZNN             Yes  No internet service  No internet service
#
#                device_protection  ... paperless_billing monthly_charges  \
# customer_id                       ...
# 7439-DKZTW                    No  ...               Yes           80.55
# 0557-ASKVU                   Yes  ...               Yes           54.40
# 7255-SSFBC                   Yes  ...               Yes          112.25
# 0311-QYWSS                    No  ...               Yes           49.45
# 1926-QUZNN   No internet service  ...               Yes           25.25
#
#             total_charges churn   contract_type  internet_service_type  \
# customer_id
# 7439-DKZTW          80.55    No  Month-to-month            Fiber optic
# 0557-ASKVU         957.10    No        One year                    DSL
# 7255-SSFBC        8041.65    No        Two year            Fiber optic
# 0311-QYWSS         314.60    No  Month-to-month                    DSL
# 1926-QUZNN        1841.20    No        Two year                   None
#
#                           payment_type One_year_con Two_year_con  \
# customer_id
# 7439-DKZTW            Electronic check            0            0
# 0557-ASKVU     Credit card (automatic)            1            0
# 7255-SSFBC   Bank transfer (automatic)            0            1
# 0311-QYWSS            Electronic check            0            0
# 1926-QUZNN   Bank transfer (automatic)            0            1
#
#             has_phone_service
# customer_id
# 7439-DKZTW                  1
# 0557-ASKVU                  1
# 7255-SSFBC                  1
# 0311-QYWSS                  1
# 1926-QUZNN                  1
#
# [5 rows x 23 columns]

# %%
train.loc[:, 'has_no_internet'] = (train.internet_service_type == 'None').astype(int)
train.head()
# Out:
#              gender  senior_citizen partner dependents  tenure phone_service  \
# customer_id
# 7439-DKZTW     Male               0      No         No       1           Yes
# 0557-ASKVU   Female               0     Yes        Yes      18           Yes
# 7255-SSFBC     Male               0     Yes        Yes      72           Yes
# 0311-QYWSS   Female               0      No         No       6           Yes
# 1926-QUZNN   Female               0     Yes         No      72           Yes
#
#             multiple_lines      online_security        online_backup  \
# customer_id
# 7439-DKZTW              No                   No                   No
# 0557-ASKVU              No                   No                   No
# 7255-SSFBC             Yes                   No                  Yes
# 0311-QYWSS              No                  Yes                   No
# 1926-QUZNN             Yes  No internet service  No internet service
#
#                device_protection  ... monthly_charges total_charges churn  \
# customer_id                       ...
# 7439-DKZTW                    No  ...           80.55         80.55    No
# 0557-ASKVU                   Yes  ...           54.40        957.10    No
# 7255-SSFBC                   Yes  ...          112.25       8041.65    No
# 0311-QYWSS                    No  ...           49.45        314.60    No
# 1926-QUZNN   No internet service  ...           25.25       1841.20    No
#
#               contract_type  internet_service_type               payment_type  \
# customer_id
# 7439-DKZTW   Month-to-month            Fiber optic           Electronic check
# 0557-ASKVU         One year                    DSL    Credit card (automatic)
# 7255-SSFBC         Two year            Fiber optic  Bank transfer (automatic)
# 0311-QYWSS   Month-to-month                    DSL           Electronic check
# 1926-QUZNN         Two year                   None  Bank transfer (automatic)
#
#             One_year_con Two_year_con has_phone_service has_no_internet
# customer_id
# 7439-DKZTW             0            0                 1               0
# 0557-ASKVU             1            0                 1               0
# 7255-SSFBC             0            1                 1               0
# 0311-QYWSS             0            0                 1               0
# 1926-QUZNN             0            1                 1               1
#
# [5 rows x 24 columns]

# %%
train[['Credit_card', 'Electronic_check', 'Mailed_check']] = pd.get_dummies(train.payment_type,
               drop_first=True).astype(int).values
train.head()
# Out:
#              gender  senior_citizen partner dependents  tenure phone_service  \
# customer_id
# 7439-DKZTW     Male               0      No         No       1           Yes
# 0557-ASKVU   Female               0     Yes        Yes      18           Yes
# 7255-SSFBC     Male               0     Yes        Yes      72           Yes
# 0311-QYWSS   Female               0      No         No       6           Yes
# 1926-QUZNN   Female               0     Yes         No      72           Yes
#
#             multiple_lines      online_security        online_backup  \
# customer_id
# 7439-DKZTW              No                   No                   No
# 0557-ASKVU              No                   No                   No
# 7255-SSFBC             Yes                   No                  Yes
# 0311-QYWSS              No                  Yes                   No
# 1926-QUZNN             Yes  No internet service  No internet service
#
#                device_protection  ...   contract_type internet_service_type  \
# customer_id                       ...
# 7439-DKZTW                    No  ...  Month-to-month           Fiber optic
# 0557-ASKVU                   Yes  ...        One year                   DSL
# 7255-SSFBC                   Yes  ...        Two year           Fiber optic
# 0311-QYWSS                    No  ...  Month-to-month                   DSL
# 1926-QUZNN   No internet service  ...        Two year                  None
#
#                           payment_type One_year_con  Two_year_con  \
# customer_id
# 7439-DKZTW            Electronic check            0             0
# 0557-ASKVU     Credit card (automatic)            1             0
# 7255-SSFBC   Bank transfer (automatic)            0             1
# 0311-QYWSS            Electronic check            0             0
# 1926-QUZNN   Bank transfer (automatic)            0             1
#
#              has_phone_service has_no_internet Credit_card Electronic_check  \
# customer_id
# 7439-DKZTW                   1               0           0                1
# 0557-ASKVU                   1               0           1                0
# 7255-SSFBC                   1               0           0                0
# 0311-QYWSS                   1               0           0                1
# 1926-QUZNN                   1               1           0                0
#
#             Mailed_check
# customer_id
# 7439-DKZTW             0
# 0557-ASKVU             0
# 7255-SSFBC             0
# 0311-QYWSS             0
# 1926-QUZNN             0
#
# [5 rows x 27 columns]

# %% [markdown]
# #### 3. Encode the categorical columns on train.
# - Encode at least one column using `.replace`
# - Encode at least one column using `.map`
# - Encode the rest of the columns by creating dummy variables and concatenating them onto the dataframe.

# %%
train.churn.map(
{'Yes': 1,
'No': 0})[:10]
# Out:
# customer_id
# 7439-DKZTW    0
# 0557-ASKVU    0
# 7255-SSFBC    0
# 0311-QYWSS    0
# 1926-QUZNN    0
# 5277-ZLOOR    1
# 1936-CZAKF    0
# 9526-JAWYF    1
# 7660-HDPJV    1
# 3027-YNWZU    0
# Name: churn, dtype: int64

# %%
train[['Phone_No','Phone_Yes']] = pd.get_dummies(train.phone_service,
               drop_first=False).astype(int).values
train.head()
# Out:
#              gender  senior_citizen partner dependents  tenure phone_service  \
# customer_id
# 7439-DKZTW     Male               0      No         No       1           Yes
# 0557-ASKVU   Female               0     Yes        Yes      18           Yes
# 7255-SSFBC     Male               0     Yes        Yes      72           Yes
# 0311-QYWSS   Female               0      No         No       6           Yes
# 1926-QUZNN   Female               0     Yes         No      72           Yes
#
#             multiple_lines      online_security        online_backup  \
# customer_id
# 7439-DKZTW              No                   No                   No
# 0557-ASKVU              No                   No                   No
# 7255-SSFBC             Yes                   No                  Yes
# 0311-QYWSS              No                  Yes                   No
# 1926-QUZNN             Yes  No internet service  No internet service
#
#                device_protection  ...               payment_type One_year_con  \
# customer_id                       ...
# 7439-DKZTW                    No  ...           Electronic check            0
# 0557-ASKVU                   Yes  ...    Credit card (automatic)            1
# 7255-SSFBC                   Yes  ...  Bank transfer (automatic)            0
# 0311-QYWSS                    No  ...           Electronic check            0
# 1926-QUZNN   No internet service  ...  Bank transfer (automatic)            0
#
#             Two_year_con has_phone_service  has_no_internet  Credit_card  \
# customer_id
# 7439-DKZTW             0                 1                0            0
# 0557-ASKVU             0                 1                0            1
# 7255-SSFBC             1                 1                0            0
# 0311-QYWSS             0                 1                0            0
# 1926-QUZNN             1                 1                1            0
#
#             Electronic_check Mailed_check Phone_No Phone_Yes
# customer_id
# 7439-DKZTW                 1            0        0         1
# 0557-ASKVU                 0            0        0         1
# 7255-SSFBC                 0            0        0         1
# 0311-QYWSS                 1            0        0         1
# 1926-QUZNN                 0            0        0         1
#
# [5 rows x 29 columns]

# %%
train = train.drop(columns = 'phone_service')

# %%
train.loc[:, 'is_churn'] = (train.churn == 'Yes').astype(int)
train.head()
# Out:
#              gender  senior_citizen partner dependents  tenure phone_service  \
# customer_id
# 7439-DKZTW     Male               0      No         No       1           Yes
# 0557-ASKVU   Female               0     Yes        Yes      18           Yes
# 7255-SSFBC     Male               0     Yes        Yes      72           Yes
# 0311-QYWSS   Female               0      No         No       6           Yes
# 1926-QUZNN   Female               0     Yes         No      72           Yes
#
#             multiple_lines      online_security        online_backup  \
# customer_id
# 7439-DKZTW              No                   No                   No
# 0557-ASKVU              No                   No                   No
# 7255-SSFBC             Yes                   No                  Yes
# 0311-QYWSS              No                  Yes                   No
# 1926-QUZNN             Yes  No internet service  No internet service
#
#                device_protection  ... One_year_con Two_year_con  \
# customer_id                       ...
# 7439-DKZTW                    No  ...            0            0
# 0557-ASKVU                   Yes  ...            1            0
# 7255-SSFBC                   Yes  ...            0            1
# 0311-QYWSS                    No  ...            0            0
# 1926-QUZNN   No internet service  ...            0            1
#
#             has_phone_service has_no_internet  Credit_card  Electronic_check  \
# customer_id
# 7439-DKZTW                  1               0            0                 1
# 0557-ASKVU                  1               0            1                 0
# 7255-SSFBC                  1               0            0                 0
# 0311-QYWSS                  1               0            0                 1
# 1926-QUZNN                  1               1            0                 0
#
#             Mailed_check Phone_No Phone_Yes is_churn
# customer_id
# 7439-DKZTW             0        0         1        0
# 0557-ASKVU             0        0         1        0
# 7255-SSFBC             0        0         1        0
# 0311-QYWSS             0        0         1        0
# 1926-QUZNN             0        0         1        0
#
# [5 rows x 30 columns]

# %%
train = train.drop(columns = 'phone_service')

# %%
train = train.drop(columns = ['churn','phone_service','contract_type', 'internet_service_type','device_protection', 'dependents', 'senior_citizen', 'online_backup', 'device_protection','online_security', 'paperless_billing','gender','partner', 'tech_support', 'streaming_tv', 'streaming_movies', 'multiple_lines', 'payment_type'])

# %%
train.head()
# Out:
#              tenure  monthly_charges  total_charges  One_year_con  \
# customer_id
# 7439-DKZTW        1            80.55          80.55             0
# 0557-ASKVU       18            54.40         957.10             1
# 7255-SSFBC       72           112.25        8041.65             0
# 0311-QYWSS        6            49.45         314.60             0
# 1926-QUZNN       72            25.25        1841.20             0
#
#              Two_year_con  has_phone_service  has_no_internet  Credit_card  \
# customer_id
# 7439-DKZTW              0                  1                0            0
# 0557-ASKVU              0                  1                0            1
# 7255-SSFBC              1                  1                0            0
# 0311-QYWSS              0                  1                0            0
# 1926-QUZNN              1                  1                1            0
#
#              Electronic_check  Mailed_check  Phone_No  Phone_Yes  is_churn
# customer_id
# 7439-DKZTW                  1             0         0          1         0
# 0557-ASKVU                  0             0         0          1         0
# 7255-SSFBC                  0             0         0          1         0
# 0311-QYWSS                  1             0         0          1         0
# 1926-QUZNN                  0             0         0          1         0

# %% [markdown]
# #### 4. Repeat the same steps on validate and test.

# %%
val[['One_year_con', 'Two_year_con']] = pd.get_dummies(val.contract_type,drop_first=True).astype(int).values
val.loc[:, 'has_phone_service'] = (val.phone_service == 'Yes').astype(int)
val.loc[:, 'has_no_internet'] = (val.internet_service_type == 'None').astype(int)
val[['Credit_card', 'Electronic_check', 'Mailed_check']] = pd.get_dummies(val.payment_type,drop_first=True).astype(int).values
val[['Phone_No','Phone_Yes']] = pd.get_dummies(val.phone_service,drop_first=False).astype(int).values
val.loc[:, 'is_churn'] = (val.churn == 'Yes').astype(int)

val.head()
# Out:
#              gender  senior_citizen partner dependents  tenure phone_service  \
# customer_id
# 4760-THGOT   Female               0     Yes         No      43           Yes
# 4023-RTIQM   Female               1     Yes         No      31            No
# 3407-QGWLG     Male               0      No        Yes       3           Yes
# 5642-MHDQT   Female               0     Yes        Yes      53           Yes
# 7080-TNUWP     Male               0     Yes         No      70           Yes
#
#                multiple_lines      online_security        online_backup  \
# customer_id
# 4760-THGOT                Yes                  Yes                  Yes
# 4023-RTIQM   No phone service                  Yes                  Yes
# 3407-QGWLG                 No  No internet service  No internet service
# 5642-MHDQT                 No  No internet service  No internet service
# 7080-TNUWP                Yes                   No                  Yes
#
#                device_protection  ... One_year_con Two_year_con  \
# customer_id                       ...
# 4760-THGOT                    No  ...            0            0
# 4023-RTIQM                   Yes  ...            1            0
# 3407-QGWLG   No internet service  ...            0            0
# 5642-MHDQT   No internet service  ...            1            0
# 7080-TNUWP                   Yes  ...            1            0
#
#             has_phone_service has_no_internet  Credit_card  Electronic_check  \
# customer_id
# 4760-THGOT                  1               0            0                 1
# 4023-RTIQM                  0               0            1                 0
# 3407-QGWLG                  1               1            0                 0
# 5642-MHDQT                  1               1            0                 0
# 7080-TNUWP                  1               0            0                 0
#
#             Mailed_check Phone_No Phone_Yes is_churn
# customer_id
# 4760-THGOT             0        0         1        0
# 4023-RTIQM             0        1         0        0
# 3407-QGWLG             1        0         1        0
# 5642-MHDQT             0        0         1        0
# 7080-TNUWP             0        0         1        0
#
# [5 rows x 30 columns]

# %%
val = val.drop(columns = ['churn','phone_service','contract_type', 'internet_service_type','device_protection', 'dependents', 'senior_citizen', 'online_backup', 'device_protection','online_security', 'paperless_billing','gender','partner', 'tech_support', 'streaming_tv', 'streaming_movies', 'multiple_lines', 'payment_type'])
val.head()
# Out:
#              tenure  monthly_charges  total_charges  One_year_con  \
# customer_id
# 4760-THGOT       43            94.10        4107.30             0
# 4023-RTIQM       31            50.40        1580.10             1
# 3407-QGWLG        3            20.05          75.45             0
# 5642-MHDQT       53            19.85        1039.45             1
# 7080-TNUWP       70            95.00        6602.90             1
#
#              Two_year_con  has_phone_service  has_no_internet  Credit_card  \
# customer_id
# 4760-THGOT              0                  1                0            0
# 4023-RTIQM              0                  0                0            1
# 3407-QGWLG              0                  1                1            0
# 5642-MHDQT              0                  1                1            0
# 7080-TNUWP              0                  1                0            0
#
#              Electronic_check  Mailed_check  Phone_No  Phone_Yes  is_churn
# customer_id
# 4760-THGOT                  1             0         0          1         0
# 4023-RTIQM                  0             0         1          0         0
# 3407-QGWLG                  0             1         0          1         0
# 5642-MHDQT                  0             0         0          1         0
# 7080-TNUWP                  0             0         0          1         0

# %%
test[['One_year_con', 'Two_year_con']] = pd.get_dummies(test.contract_type, drop_first=True).astype(int).values
test.loc[:, 'has_phone_service'] = (test.phone_service == 'Yes').astype(int)
test.loc[:, 'has_no_internet'] = (test.internet_service_type == 'None').astype(int)
test[['Credit_card', 'Electronic_check', 'Mailed_check']] = pd.get_dummies(test.payment_type, drop_first=True).astype(int).values
test[['Phone_No','Phone_Yes']] = pd.get_dummies(test.phone_service,drop_first=False).astype(int).values
test.loc[:, 'is_churn'] = (test.churn == 'Yes').astype(int)

test.head()
# Out:
#              gender  senior_citizen partner dependents  tenure phone_service  \
# customer_id
# 3739-YBWAB     Male               0     Yes         No      36            No
# 3654-ARMGP   Female               0      No         No      61           Yes
# 9220-CXRSC   Female               0     Yes        Yes      69           Yes
# 7997-EASSD   Female               0     Yes         No      63           Yes
# 7595-EHCDL     Male               0     Yes        Yes      32            No
#
#                multiple_lines online_security online_backup device_protection  \
# customer_id
# 3739-YBWAB   No phone service             Yes            No               Yes
# 3654-ARMGP                Yes              No           Yes               Yes
# 9220-CXRSC                Yes             Yes            No                No
# 7997-EASSD                Yes              No            No                No
# 7595-EHCDL   No phone service              No            No               Yes
#
#              ... One_year_con Two_year_con has_phone_service has_no_internet  \
# customer_id  ...
# 3739-YBWAB   ...            1            0                 0               0
# 3654-ARMGP   ...            0            1                 1               0
# 9220-CXRSC   ...            0            1                 1               0
# 7997-EASSD   ...            1            0                 1               0
# 7595-EHCDL   ...            0            0                 0               0
#
#              Credit_card  Electronic_check Mailed_check Phone_No Phone_Yes  \
# customer_id
# 3739-YBWAB             0                 0            1        1         0
# 3654-ARMGP             1                 0            0        0         1
# 9220-CXRSC             1                 0            0        0         1
# 7997-EASSD             1                 0            0        0         1
# 7595-EHCDL             1                 0            0        1         0
#
#             is_churn
# customer_id
# 3739-YBWAB         0
# 3654-ARMGP         0
# 9220-CXRSC         0
# 7997-EASSD         0
# 7595-EHCDL         0
#
# [5 rows x 30 columns]

# %%
test = test.drop(columns = ['churn','phone_service','contract_type', 'internet_service_type','device_protection', 'dependents', 'senior_citizen', 'online_backup', 'device_protection','online_security', 'paperless_billing','gender','partner', 'tech_support', 'streaming_tv', 'streaming_movies', 'multiple_lines', 'payment_type'])
test.head()
# Out:
#              tenure  monthly_charges  total_charges  One_year_con  \
# customer_id
# 3739-YBWAB       36            35.35        1317.95             1
# 3654-ARMGP       61            88.65        5321.25             0
# 9220-CXRSC       69            61.40        4059.85             0
# 7997-EASSD       63            81.20        4965.10             1
# 7595-EHCDL       32            50.60        1653.45             0
#
#              Two_year_con  has_phone_service  has_no_internet  Credit_card  \
# customer_id
# 3739-YBWAB              0                  0                0            0
# 3654-ARMGP              1                  1                0            1
# 9220-CXRSC              1                  1                0            1
# 7997-EASSD              0                  1                0            1
# 7595-EHCDL              0                  0                0            1
#
#              Electronic_check  Mailed_check  Phone_No  Phone_Yes  is_churn
# customer_id
# 3739-YBWAB                  0             1         1          0         0
# 3654-ARMGP                  0             0         0          1         0
# 9220-CXRSC                  0             0         0          1         0
# 7997-EASSD                  0             0         0          1         0
# 7595-EHCDL                  0             0         1          0         0

# %% [markdown]
# #### 5. Create a function named `prep_telco` that accepts the train, validate, and test telco data, and returns the dataframes ready for modeling.

# %%
def preprocess_telco(train, val, test, continuous_features=['tenure', 'monthly_charges', 'total_charges']):
    
    '''
    preprocess telco will encode any categorical features
    and proceed forward with using a minmax scaler to transform 
    continuous variables.
    
    return: three dataframes, train, validate, and test, preprocessed for modeling
    '''
    # iterate through our three dataframes
    for df in [train, val, test]:
        # assign out the encoded categoricals for 
        # in the same way on all three datasets
        df[['One_year_contract', 'Two_year_contract']] = pd.get_dummies(df.contract_type,
               drop_first=True).astype(int).values
        

    
   
   
    
    df.loc[:, 'has_phone_service'] = (df.phone_service == 'Yes').astype(int)
    df.loc[:, 'has_no_internet'] = (df.internet_service_type == 'None').astype(int)
    df.loc[:, 'is_churn'] = (df.churn == 'Yes').astype(int)
    
    df.loc[:,'internet_service_type'] = df.internet_service_type.fillna('no internet')
    df = df.set_index('customer_id')
    df.loc[:,'total_charges'] = (df.total_charges + '0')
    df.total_charges = df.total_charges.astype(float)
    return df

     # create a single scaler object
    scaler = MinMaxScaler()
    # fit the single scaler just once to train
    scaler.fit(train[continuous_features])
    # apply that transformation to all three data sets
    # using the same syntax, which conconates
    # '_scaled' to each feature name that was fed in
    for df in [train, val, test]:
        df[[continuous_features[0]+'_scaled', continuous_features[1]+'_scaled']] = \
        scaler.transform(df[continuous_features])
    for df in [train, val, test]:
        df[['Churn_No','Churn_Yes']] = pd.get_dummies(df.churn, drop_first=False).astype(int).values
        df[['Credit_card', 'Electronic_check', 'Mailed_check']] = pd.get_dummies(df.payment_type,
               drop_first=True).astype(int).values
        df[['One_year_con', 'Two_year_con']] = pd.get_dummies(df.contract_type,
               drop_first=True).astype(int).values    
    preprocessed_dfs = []
    for df in [train, val, test]:
        preprocessed_dfs.append(df.drop(columns=['Unnamed: 0',
        'internet_service_type_id',
        'payment_type_id',
        'contract_type_id', 
        'churn','phone_service',
        'contract_type', 
        'internet_service_type',
        'device_protection', 
        'dependents', 'senior_citizen', 
        'online_backup', 'device_protection',
        'online_security', 'paperless_billing',
        'gender','partner', 'tech_support',
        'streaming_tv', 'streaming_movies', 
        'multiple_lines', 'payment_type']))
    return preprocessed_dfs
